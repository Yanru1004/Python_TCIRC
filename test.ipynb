# %%
with open(r"C:\Users\user\Desktop\題目.txt",'r',encoding='utf-8') as fin:
    line = 1
    for li in fin.readlines():
        title = li.split()[0]
        with open(f"C:\\Users\\user\\Desktop\\範本\\TCIRC_b{line:03d}.py",'w',encoding='utf-8') as f:
            f.write(f'#b{line:03d} {title}\n')
        line += 1
    print(f'\n{line}')
# Out:
# 52

# %%
# Out:
# -1
# 1
# 0
